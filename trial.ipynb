# %%
import tensorflow as tf
import os
import numpy as np
from PIL import Image
import sklearn.model_selection as ms
import matplotlib.pyplot as plt

# %% [markdown]
# Helper Functions

# %%
def images2ArrayList(sourceFolder, label, howMany):
    '''converts images to arrays and returns them as list'''
    os.chdir(sourceFolder)
    filenames = os.listdir()
    data = []
    labels = [label for i in range(howMany)]
    for i in range(howMany):
        image = Image.open(filenames[i])
        array = np.asarray(image)
        data.append(array)
    return data, labels

def loadTrainTest(root):
    '''loads the dataset'''
    sourceFolder = root + '/200x200/NORMAL'
    normal, normal_label = images2ArrayList(sourceFolder, 0, 1583)
    sourceFolder = root + '/200x200/PNEUMONIA'
    pneumonia, pneumonia_label = images2ArrayList(sourceFolder, 1, 4273)
    images = normal + pneumonia
    label = normal_label + pneumonia_label
    return (np.array(images), np.array(label))

# %% [markdown]
# Load The Dataset

# %%
root = os.getcwd()

img, label = loadTrainTest(root)
img = img / 255   #normalize
x_train, x_test, y_train, y_test = ms.train_test_split(img, label, train_size=.9)

# %% [markdown]
# Build, compile and train the model

# %%
model = tf.keras.models.Sequential([

#--------------------------conv layers--------------------------
    #conv+maxpool: 200x200 => 100x100, 4 filters
    tf.keras.layers.Conv2D(4, 
                           (3, 3), 
                           activation='relu',
                           padding='same',
                           input_shape=(200, 200,1)),
    tf.keras.layers.MaxPooling2D((2, 2)),
    
    #conv+maxpool: 100x100 => 50x50, 8 filters
    tf.keras.layers.Conv2D(8,
                           (3, 3), 
                           activation='relu',
                           padding='same',
                           input_shape=(100, 100,1)),
    tf.keras.layers.MaxPooling2D((2, 2)),
    
    #conv+maxpool: 50x50 => 25x25, 16 filters
    tf.keras.layers.Conv2D(16,
                           (3, 3), 
                           activation='relu',
                           padding='same',
                           input_shape=(50, 50,1)),
    tf.keras.layers.MaxPooling2D((2, 2)),

#------------------------dense layers-----------------------------------
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dropout(.5),
    
    tf.keras.layers.Dense(400, 
                          activation='relu', 
                          kernel_regularizer=tf.keras.regularizers.l2(0.0001)), 
    tf.keras.layers.Dropout(.5),
    
    tf.keras.layers.Dense(100, 
                        activation='relu', 
                        kernel_regularizer=tf.keras.regularizers.l2(0.0001)), 
    tf.keras.layers.Dropout(.5),
    
    tf.keras.layers.Dense(1, activation='sigmoid')

    
])

model.compile(optimizer='Adam',
              loss='BinaryCrossentropy',
              metrics=['accuracy', 'Precision', 'Recall'])
history = model.fit(
        x_train.reshape(len(x_train), 200, 200, 1), y_train, epochs=10,
        validation_data=(x_test.reshape(len(x_test), 200, 200, 1), y_test))
# Out:
# Epoch 1/10
# 165/165 [==============================] - 45s 273ms/step - loss: 0.4130 - accuracy: 0.8505 - precision: 0.8687 - recall: 0.9365 - val_loss: 0.2146 - val_accuracy: 0.9471 - val_precision: 0.9717 - val_recall: 0.9559
# Epoch 2/10
# 165/165 [==============================] - 46s 278ms/step - loss: 0.2545 - accuracy: 0.9292 - precision: 0.9462 - recall: 0.9573 - val_loss: 0.2044 - val_accuracy: 0.9454 - val_precision: 0.9483 - val_recall: 0.9791
# Epoch 3/10
# 165/165 [==============================] - 45s 276ms/step - loss: 0.2313 - accuracy: 0.9366 - precision: 0.9528 - recall: 0.9607 - val_loss: 0.2200 - val_accuracy: 0.9437 - val_precision: 0.9403 - val_recall: 0.9861
# Epoch 4/10
# 165/165 [==============================] - 46s 276ms/step - loss: 0.2041 - accuracy: 0.9454 - precision: 0.9613 - recall: 0.9638 - val_loss: 0.1746 - val_accuracy: 0.9573 - val_precision: 0.9656 - val_recall: 0.9768
# Epoch 5/10
# 165/165 [==============================] - 46s 281ms/step - loss: 0.2000 - accuracy: 0.9471 - precision: 0.9588 - recall: 0.9690 - val_loss: 0.1751 - val_accuracy: 0.9573 - val_precision: 0.9614 - val_recall: 0.9814
# Epoch 6/10
# 165/165 [==============================] - 46s 279ms/step - loss: 0.1831 - accuracy: 0.9533 - precision: 0.9651 - recall: 0.9711 - val_loss: 0.1682 - val_accuracy: 0.9573 - val_precision: 0.9699 - val_recall: 0.9722
# Epoch 7/10
# 165/165 [==============================] - 47s 283ms/step - loss: 0.1753 - accuracy: 0.9556 - precision: 0.9693 - recall: 0.9698 - val_loss: 0.1767 - val_accuracy: 0.9539 - val_precision: 0.9550 - val_recall: 0.9838
# Epoch 8/10
# 165/165 [==============================] - 46s 281ms/step - loss: 0.1781 - accuracy: 0.9583 - precision: 0.9675 - recall: 0.9755 - val_loss: 0.1743 - val_accuracy: 0.9590 - val_precision: 0.9615 - val_recall: 0.9838
# Epoch 9/10
# 165/165 [==============================] - 46s 281ms/step - loss: 0.1705 - accuracy: 0.9632 - precision: 0.9723 - recall: 0.9774 - val_loss: 0.1676 - val_accuracy: 0.9608 - val_precision: 0.9722 - val_recall: 0.9745
# Epoch 10/10
# 165/165 [==============================] - 46s 281ms/step - loss: 0.1746 - accuracy: 0.9569 - precision: 0.9669 - recall: 0.9742 - val_loss: 0.1793 - val_accuracy: 0.9608 - val_precision: 0.9789 - val_recall: 0.9675

# %% [markdown]
# Accuracy and loss plot

# %%
plt.plot(history.history['accuracy'], label='train')
plt.plot(history.history['val_accuracy'], label = 'test')
plt.xlabel('Epoch')
plt.title('Accuracy')
plt.legend(loc='lower right')
plt.show()

plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label = 'test')
plt.xlabel('Epoch')
plt.title('Loss')
plt.legend()
plt.show()

plt.plot(history.history['precision'], label='train')
plt.plot(history.history['val_precision'], label = 'test')
plt.xlabel('Epoch')
plt.title('Precision')
plt.legend()
plt.show()

plt.plot(history.history['recall'], label='train')
plt.plot(history.history['val_recall'], label = 'test')
plt.xlabel('Epoch')
plt.title('Recall')
plt.legend()
plt.show()

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 200, 200, 4)       40
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 100, 100, 4)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 100, 100, 8)       296
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 50, 50, 8)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 50, 50, 16)        1168
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 25, 25, 16)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 10000)             0
# _________________________________________________________________
# dropout (Dropout)            (None, 10000)             0
# _________________________________________________________________
# dense (Dense)                (None, 400)               4000400
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 400)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               40100
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 101
# =================================================================
# Total params: 4,042,105
# Trainable params: 4,042,105
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Save model

# %%
model.save(root + '/model.h5')
